# %%
# 시스템에 설치된 NVIDIA GPU의 정보를 표시
# !nvidia-smi #GPU에 액세스할 수 있는지 확인
# Out:
# Tue Oct 10 13:17:37 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8     9W /  70W |      3MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# 현재 작업 디렉토리
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# Pip install method (recommended)
# Ultralytics 라이브러리를 설치
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.8/78.2 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
# datasets 디렉토리 생성&이
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# Roboflow 라이브러리 설치
# !pip install roboflow --quiet

# Roboflow API를 사용하여 hardhat 작업자 데이터셋 다운로드
from roboflow import Roboflow
rf = Roboflow(api_key="jMIdZJA4uAXGfG2DqOQN")
project = rf.workspace("mnist-bvalq").project("mnist-icrul")
dataset = project.version(8).download("yolov8")
# Out:
# mkdir: cannot create directory ‘/content/datasets’: File exists
# /content/datasets
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.134 is required but found version=8.0.20, to fix: `pip install ultralytics==8.0.134`
# ...
# Extracting Dataset Version Zip to MNIST-8 in yolov8:: 100%|██████████| 14270/14270 [00:04<00:00, 2957.99it/s]

# %%
# %cd {HOME}
# plots 학습 과정을 시각화할지 여부를 제어
# imgsz img size
# !yolo task=detect mode=train model=yolov8n.pt data={dataset.location}/data.yaml epochs=50 imgsz=200 plots=True

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !ls {HOME}/runs/detect/train/

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=200)

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/results.png', width=200)

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=200)

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source={dataset.location}/test/images save=True

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/runs/detect/predict3/*.jpg')[:3]:
      display(Image(filename=image_path, width=416))
      print("\n")
